# %% [markdown]
# <div style="border:solid Green 2px; border-radius: 10px;  padding: 40px">
# <b>Привет, Алексей!👋</b>
#
# Меня зовут Зуева Юлия, можно просто Юля 😏 Я буду ревьюером твоего проекта. Предлагаю обращаться на "ты", но если это неудобно, пожалуйста, скажи об этом!
#
# Моя основная цель - помочь тебе стать компетентным Data Scientist'ом: вместе преодолеть трудности и еще больше развить твои сильные навыки 💪 В твоей работе я оставила комментарии, которые должны в этом помочь. Для твоего удобства комментарии расскрашены разными цветами:
# <br/>
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> В случае корректного решения (или отдельных его моментов). На такие решения можно опираться в будущем.
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b> Если есть возможность как-либо улучшить решение. Ты можешь учесть эти комментарии при доработке проекта, однако для зачета это не обязательно.
# </div>
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
# <b>Нужно доработать ❌:</b> Если решение требует внесения правок. Проект не может быть принят, если остались не отработанные комментарии данного типа.
# </div>
#
# Чтобы наша с тобой работа была еще эффективнее, ты точно так же можешь оставлять комментарии и задавать мне вопросы. Для таких случаев, пожалуйста, выбери собственное оформление комментариев, которое будет отличаться от моего, чтобы не создавалась путаница. По этой же причине попрошу тебя не удалять и не изменять мои комментарии. Все это позволит лучше ориентироваться в нашем с тобой диалоге, а повторную проверку (в случае ее необходимости) выполнять оперативнее 🚀
#
# Не спеши расстраиваться, если что-то не удалось с первого раза. Вместе мы обязательно разберемся со всеми трудностями! 🤓

# %% [markdown]
# <div style="border:solid blue 2px; border-radius: 10px;  padding: 15px">
# Юля, привет. Спасибо за обратную связь и да, давай на ты.
# </div>

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши
#
# Автор: Ильин А.В.\
# Дата: 21.10.2025

# %% [markdown]
# **Цель:** Провести исследовательский анализ данных Яндекс Афиши, для выявления пользователей, которые с большей вероятностью возвращаются на платформу и делают заказы повторно.
#
# **Структура проекта:**
# 1. Загрузка данных и знакомство с ними.
# 2. Предобработка данных.
# 3. Создание профиля пользователя
# 4. Исследовательский анализ данных.
# 5. Общий вывод и рекомендации.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px; border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Вводная часть <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b> В любой работе важно оставлять вводную часть. Она помогает быстро понять цель, контекст и структуру работы, что будет удобно не только для тебя при возвращении к проекту спустя время, но и любому другому читателю (если, например, публикуешь в открытый доступ для портфолио). Воспринимаем эту тетрадку не просто как выполнение домашней работы на курсе, а как полноценный исследовательский проект.
#
# Как правило, в вводную часть включают название проекта, краткое описание цели, используемых данных (источники, объем, особенности), нюансы самого проекта (специфические условия, ограничения, предположения и т.д.). Иногда также сразу обозначают план шагов. Другими словами, вводная часть призвана отразить, что мы делаем, с чем работаем и на каких условиях.
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; border-radius: 10px;  padding: 15px">
# <h3> Комментарий студента <a class="tocSkip"></h3>
#
# Добавил вводную часть.
# </div>

# %% [markdown]
# ## Загрузка данных и их предобработка
#
# ---
#
# **Задача 1.1:** Напишите SQL-запрос, выгружающий в датафрейм pandas необходимые данные. Используйте следующие параметры для подключения к базе данных `data-analyst-afisha`:
#
# Для выгрузки используйте запрос из предыдущего урока и библиотеку SQLAlchemy.
#
# Выгрузка из базы данных SQL должна позволить собрать следующие данные:
#
# - `user_id` — уникальный идентификатор пользователя, совершившего заказ;
# - `device_type_canonical` — тип устройства, с которого был оформлен заказ (`mobile` — мобильные устройства, `desktop` — стационарные);
# - `order_id` — уникальный идентификатор заказа;
# - `order_dt` — дата создания заказа (используйте данные `created_dt_msk`);
# - `order_ts` — дата и время создания заказа (используйте данные `created_ts_msk`);
# - `currency_code` — валюта оплаты;
# - `revenue` — выручка от заказа;
# - `tickets_count` — количество купленных билетов;
# - `days_since_prev` — количество дней от предыдущей покупки пользователя, для пользователей с одной покупкой — значение пропущено;
# - `event_id` — уникальный идентификатор мероприятия;
# - `service_name` — название билетного оператора;
# - `event_type_main` — основной тип мероприятия (театральная постановка, концерт и так далее);
# - `region_name` — название региона, в котором прошло мероприятие;
# - `city_name` — название города, в котором прошло мероприятие.
#
# ---

# %% [markdown]
# Сделаем подключение к базе данных.

# %%
# Устанавливаем необходимые библиотеки
# !pip install -q sqlalchemy
# !pip install -q psycopg2-binary
# !pip install -q dotenv
# !pip install -q phik

# %%
# Импортируем библиотеки
from dotenv import load_dotenv
import os
from sqlalchemy import create_engine
import pandas as pd
from phik import phik_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div style="border:solid #D3D3D3 2px; border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Импорты <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> Здорово, что все необходимые библиотеки подгружаешь сразу в начале проекта! Это соответсвует стандартам оформления кода <a href='https://pyplanet.ru/article/pep-0008.html'>PEP 8</a>. Такой подход позволяет сразу видеть, какое окружение необходимо для запуска проекта, избежать дублирования импортов в разных частях кода, а также облегчить отладку и переносимость проекта.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Хорошей практикой также является упорядочивание импортов. PEP 8 рекомендует снчала подгружать стандартные python-библиотеки, затем сторонние. Но для удобства каждую их этих групп также можно стуктурировать по тематике. Например, библиотеки для работы с данными, для работы с графиками и т.д. Тогда будет удобнее поддерживать порядок в импортах от проекта к проекту, не подгружать лишнее.
#
#
# * Чтобы при установке новой библиотеки не выводилась информация о процессе и зависимостях, можно добывлять опцию `--quiet` или просто `-q`.
#
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; border-radius: 10px;  padding: 15px">
# <h3> Комментарий студента <a class="tocSkip"></h3>
#
# Поправил.
# </div>

# %%
load_dotenv(dotenv_path="./local.env")

connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    os.getenv('DB_USER'),
    os.getenv('DB_PASSWORD'),
    os.getenv('DB_HOST'),
    os.getenv('DB_PORT'),
    os.getenv('DB_NAME'),
)

# %%
# Подключаемся к бд
engine = create_engine(connection_string)

# %%
# Формируем SQL запрос
query = '''
select
  user_id,
  device_type_canonical,
  order_id,
  created_dt_msk as order_dt,
  created_ts_msk as order_ts,
  currency_code,
  revenue,
  tickets_count,
  extract('days' from created_dt_msk - lag(created_dt_msk) over(partition by user_id order by created_dt_msk)) as days_since_prev,
  event_id,
  event_name_code as event_name,
  event_type_main,
  service_name,
  region_name,
  city_name
from afisha.purchases
left join afisha.events using (event_id)
left join afisha.city using (city_id)
left join afisha.regions using (region_id)
where device_type_canonical in ('mobile', 'desktop') and event_type_main != 'фильм'
order by user_id
'''

# %%
# Выгружаем данные в переменную df
df = pd.read_sql_query(query, con=engine)

# %% [markdown]
# <div style="border:solid #D3D3D3 2px; border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Загрузка данных <a class="tocSkip"></h4>
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> Выгрузка данных проведена корректно! Была выполнена необходимая фильтрация данных, выгружены только необходимые для анализа данные. Отлично, что сразу подсчитываешь время между заказами для каждого пользователя.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
# <b>Нужно доработать ❌:</b> Сейчас ты явным образом прописываешь параметры подключения к БД. В таком виде выкладывать работу в публичный доступ небезопасно, кто-то сможет завладеть подключением, украсть или повредить данные. Лучше сразу в процессе работы держать чувствиительные значения отдельно от основного содержания, иначе есть высокий риск забыть об этом нюансе. По этой же причине лучше убрать ключи и из описания задания.
#
# Чтобы засекретить подключение, необходимо сложить все параметры в `.env` файл (или другой конфигурационный файл вне Git) и указать его в `.gitignore`:
#
# ```python
# DB_NAME="..."
# DB_HOST="..."
# DB_PORT="..."
# DB_USER="..."
# DB_PASSWORD="..."
# ```
#
# В самом проекте мы можем обращаться к сохраненным параметрам, для этого нам потребуются библиотеки `dotenv`, чтобы загрузить переменные окружения, и `os`, чтобы обратиться к ним:
#
# ```python
# import os
# import dotenv
#
# load_dotenv() # автоматически ищет .env в текущей директории
#
# connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
#     os.getenv('DB_USER'),
#     os.getenv('DB_PASSWORD'),
#     os.getenv('DB_HOST'),
#     os.getenv('DB_PORT'),
#     os.getenv('DB_NAME'),
# )
# ```
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; border-radius: 10px;  padding: 15px">
# <h3> Комментарий студента <a class="tocSkip"></h3>
#
# Вынес параметры подключения в local.env
# </div>

# %% [markdown]
# ---
#
# **Задача 1.2:** Изучите общую информацию о выгруженных данных. Оцените корректность выгрузки и объём полученных данных.
#
# Предположите, какие шаги необходимо сделать на стадии предобработки данных — например, скорректировать типы данных.
#
# Зафиксируйте основную информацию о данных в кратком промежуточном выводе.
#
# ---

# %%
# Выводим первые строки датафрейма df
df.head()
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             75.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
#
#    event_id                            event_name event_type_main  \
# ...

# %%
# Выводим информацию о датафрейме
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name             290611 non-null  object
#  11  event_type_main        290611 non-null  object
#  12  service_name           290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %% [markdown]
# Датафрейм `df` содержит 15 столбцов и 290611 строк, в которых представлена информация о заказах сделанных на Яндекс Афише.
#
# После первичного анализа данных можно сделать следующие выводы:
# - Все представленные данные имеют правильный тип. Можно попробовать оптимизировать разрядность типов данных в столбцах с числовыми данными.
# - Пропуски содержатся только в столбце `days_since_prev`. Для пользователей с одной покупкой значение в этом столбце пропущено, т.к. нет предыдущей покупки.
# - Судя по первому знакомству с данными, значения в столбцах соответствуют своему описанию.
#
# Далее проведем предобработку данных, проведем поиск полных и неявных дубликатов, проверим категоральные данные на корректность и числовые данные на наличие выьросов и аномалий.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px; border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Проверка корректности загруженных данных <a class="tocSkip"></h4>
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b>
#
# * Хорошо, что убеждаешь в корректности данных! Если при подгрузке возникли проблемы, а мы их не обнаружим, все последующие расчеты могут быть искажены.
#
#
# * Круто, что не забываешь зафиксировать промежуточные наблюдения в выводах! Если потребуется вернуться к проекту спустя время, будет проще освежить в памяти все ключевые этапы работы, что и почему мы делали, что получили.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * По результатам проверки корректности загруженных данных мы планируем дальнейшие шаги по обработке данных. Здесь также можно было отметить, что нам потребуется выполнить проверку на дубликаты (полные и неполные), проверить категориальные столбцы на предмет неявных дубликатов (разный регистр, разный формат записи, опечатки) и числовые столбцы на наличие аномалий и невалидных значений.
#
#
# * Было бы не лишним пояснить, почему в `days_since_prev` могут наблюдаться пропуски, проблам ли это, или это нормальная ситауция. В нашем случае, скорее всего, пропуски образовались только на первых заказах пользователей, в таком случае у них не существует предыдущего, от которого можно было бы посчитать количество дней.
#
#
# * Обрати внимание, что если не ограничивать количество выводимой информации, то вывод ограничится только при отображении, но в json (в виде которых хранятся jupyter-ноутбуки) на диске будут все данные, что будет тормозить открытие и работу тетрадки. Чтобы такого не происходило, следует ограничивать вывод несколькими строками: `head`, `tail`, `sample`.
#
# </div>

# %% [markdown]
# ---
#
# ##  Предобработка данных
#
# Выполните все стандартные действия по предобработке данных:
#
# ---
#
# **Задача 2.1:** Данные о выручке сервиса представлены в российских рублях и казахстанских тенге. Приведите выручку к единой валюте — российскому рублю.
#
# Для этого используйте датасет с информацией о курсе казахстанского тенге по отношению к российскому рублю за 2024 год — `final_tickets_tenge_df.csv`. Его можно загрузить по пути `https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')`
#
# Значения в рублях представлено для 100 тенге.
#
# Результаты преобразования сохраните в новый столбец `revenue_rub`.
#
# ---

# %% [markdown]
# ### Обработка данных

# %% [markdown]
# Cоздадим копию датасета до преобразования для возможности проверить сделанные изменения после предобработки.

# %%
temp = df.copy() 
len(temp)
# Out:
# 290611

# %%
# Выгружаем данные курсов в переменную curs_df
curs_df = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')

# %%
# Проверим типы данных
curs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     357 non-null    object
#  1   nominal  357 non-null    int64
#  2   curs     357 non-null    float64
#  3   cdx      357 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 11.3+ KB

# %% [markdown]
# Столбец `data` имеет тип object, приведем его к типу datetime.

# %%
curs_df['data'] = pd.to_datetime(curs_df['data'])

# %% [markdown]
# Напишем функцию для конвертации тенге в рубли и применим ее.

# %%
def convert_tenge_to_rub(row, lookup_df):
    if row['currency_code'] == 'kzt':
        matching_row = lookup_df[lookup_df['data'] == row['order_dt']]
        return round(matching_row['curs'].iloc[0] * row['revenue'] / 100, 2)
    else:
        return row['revenue']

# %%
#df['revenue_rub'] = df.apply(lambda row: convert_tenge_to_rub(row, curs_df), axis=1)

# %% [markdown]
# Объединим датафрейм с курсами с основным датафреймом по дате.

# %%
df = df.merge(curs_df, how="left", left_on='order_dt', right_on='data')
df.head()
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             75.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
#
#    event_id                            event_name event_type_main  \
# ...

# %% [markdown]
# Добавим новый столбец с выручкой в рублях.

# %%
df['revenue_rub'] = df['revenue'].where(df['currency_code'] == 'rub', round(df['revenue'] * df['curs'] / 100, 2))

# %%
df[df['currency_code'] == 'kzt'][['order_id', 'revenue', 'currency_code', 'curs', 'revenue_rub']].head()
# Out:
#      order_id   revenue currency_code     curs  revenue_rub
# 70    7850214    518.10           kzt  19.0125        98.50
# 89    8634925    347.18           kzt  18.9330        65.73
# 96    7625522    328.77           kzt  18.5991        61.15
# 277    720419  22021.55           kzt  19.8928      4380.70
# 460   2229811   7397.66           kzt  19.9833      1478.30

# %% [markdown]
# Добавили новый столбец `revenue_rub` с выручкой в рублях.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Перевод выручки в рубли <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> С шагом справились, результат корректный! Хорошо, что убеждаешься в этом.
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Сейчас ты отдельно для каждой строки создаешь поиск в таблице с курсом, что очень неэффективно (это алгоритм с квадратичной сложностью). Было бы лучше присоединить курс к нашей основной таблице по дате, а потом уже внутри нашей таблицы производить расчет.
#
#
# * Существует также довольно удобный метод [where](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.where.html). Мы можем применить его к столбцу и указать условие, которое будем проверять, а также альтернативный вариант значения. Если условие выполняется, то берется значение из столбца, если нет - альтернативное значение. Тогда расчет выручки в рублях будет выглядеть следующим образом:
#
#     ```python
# df['revenue_rub'] = df['revenue'].where(df['currency_code'] == 'rub', df['revenue'] * df['curs'] / 100)
# ```
#
# * Чтобы не перегружать работу лишним, было бы лучше вывести только необходимые для проверки расчетов столбцы.
#
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; border-radius: 10px;  padding: 15px">
# <h3> Комментарий студента <a class="tocSkip"></h3>
#
# Переделал.
# </div>

# %% [markdown]
# ---
#
# **Задача 2.2:**
#
# - Проверьте данные на пропущенные значения. Если выгрузка из SQL была успешной, то пропуски должны быть только в столбце `days_since_prev`.
# - Преобразуйте типы данных в некоторых столбцах, если это необходимо. Обратите внимание на данные с датой и временем, а также на числовые данные, размерность которых можно сократить.
# - Изучите значения в ключевых столбцах. Обработайте ошибки, если обнаружите их.
#     - Проверьте, какие категории указаны в столбцах с номинальными данными. Есть ли среди категорий такие, что обозначают пропуски в данных или отсутствие информации? Проведите нормализацию данных, если это необходимо.
#     - Проверьте распределение численных данных и наличие в них выбросов. Для этого используйте статистические показатели, гистограммы распределения значений или диаграммы размаха.
#
#         Важные показатели в рамках поставленной задачи — это выручка с заказа (`revenue_rub`) и количество билетов в заказе (`tickets_count`), поэтому в первую очередь проверьте данные в этих столбцах.
#
#         Если обнаружите выбросы в поле `revenue_rub`, то отфильтруйте значения по 99 перцентилю.
#
# После предобработки проверьте, были ли отфильтрованы данные. Если были, то оцените, в каком объёме. Сформулируйте промежуточный вывод, зафиксировав основные действия и описания новых столбцов.
#
# ---

# %% [markdown]
# ### Проверяем наличие пропусков в данных

# %% [markdown]
# Посмотрим общее количество пропусков в датафрейме df.

# %%
df.isna().sum()
# Out:
# user_id                      0
# device_type_canonical        0
# order_id                     0
# order_dt                     0
# order_ts                     0
# currency_code                0
# revenue                      0
# tickets_count                0
# days_since_prev          21933
# event_id                     0
# event_name                   0
# event_type_main              0
# service_name                 0
# region_name                  0
# city_name                    0
# data                         0
# nominal                      0
# curs                         0
# cdx                          0
# revenue_rub                  0
# dtype: int64

# %% [markdown]
# Посчитаем долю строк с пропусками.

# %%
df.isna().sum() / df.shape[0]
# Out:
# user_id                  0.000000
# device_type_canonical    0.000000
# order_id                 0.000000
# order_dt                 0.000000
# order_ts                 0.000000
# currency_code            0.000000
# revenue                  0.000000
# tickets_count            0.000000
# days_since_prev          0.075472
# event_id                 0.000000
# event_name               0.000000
# event_type_main          0.000000
# service_name             0.000000
# region_name              0.000000
# city_name                0.000000
# data                     0.000000
# nominal                  0.000000
# curs                     0.000000
# cdx                      0.000000
# revenue_rub              0.000000
# dtype: float64

# %% [markdown]
# Пропуски содержатся только в столбце `days_since_prev`, но об этом было известно изначально, пропуски в этом столбце означают что пользовательно сделал всего один заказ. Количество пропусков 8%.

# %% [markdown]
# ### Оптимизируем типы данных

# %% [markdown]
# По итогам предварительного ознакомления c датасетом было решено попробовать оптимизировать разрядность типов данных в стобцах с числовыми данными.

# %%
df['order_id'] = pd.to_numeric(df['order_id'], downcast="integer")
df['revenue'] = pd.to_numeric(df['revenue'], downcast="float")
df['tickets_count'] = pd.to_numeric(df['tickets_count'], downcast="integer")
df['days_since_prev'] = pd.to_numeric(df['days_since_prev'], downcast="float")
df['event_id'] = pd.to_numeric(df['event_id'], downcast="integer")

# %%
# Проверим типы данных в датафрейме
df.dtypes
# Out:
# user_id                          object
# device_type_canonical            object
# order_id                          int32
# order_dt                 datetime64[ns]
# order_ts                 datetime64[ns]
# currency_code                    object
# revenue                         float32
# tickets_count                      int8
# days_since_prev                 float32
# event_id                          int32
# event_name                       object
# event_type_main                  object
# service_name                     object
# region_name                      object
# city_name                        object
# data                     datetime64[ns]
# nominal                           int64
# curs                            float64
# cdx                              object
# revenue_rub                     float64
# dtype: object

# %% [markdown]
# Получилось оптимизировать разрядность в столбцах `order_id`, `tickets_count`, `days_since_prev` и `event_id`.

# %% [markdown]
# ### Явные и неявные дубликаты в данных

# %% [markdown]
# Проверим наличие полных дубликатов в датафрейме

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# В датафрейме нет полных дубликатов.

# %% [markdown]
# Проверим на уникальность значения `order_id`.

# %%
df.duplicated(subset='order_id').sum()
# Out:
# 0

# %% [markdown]
# Все значения в столбце `order_id` уникальны.

# %% [markdown]
# Проверим наличие неявных дубликатов сделав поиск дубликатов без учета `order_id` и `days_since_prev`.

# %%
columns_for_duplicated_subset = [
    'user_id',
    'device_type_canonical',
    'order_dt',
    'order_ts',
    'currency_code',
    'revenue',
    'tickets_count',
    'event_id',
    'event_name',
    'event_type_main',
    'service_name',
    'region_name',
    'city_name'
]
df.duplicated(subset=columns_for_duplicated_subset).sum()
# Out:
# 40

# %% [markdown]
# Найдено 40 неявных дубликатов. Возможно это задублированные заказы в системе. Удалим их.

# %%
df = df.drop_duplicates(subset=columns_for_duplicated_subset)

# %% [markdown]
# Проверим уникальные значения в категориальных столбцах.

# %%
for column in ['device_type_canonical', 'currency_code', 'event_type_main']:
    print(f'Уникальные значения в столбце {column}:')
    print(df[column].sort_values().unique())
    print()
# Out:
# Уникальные значения в столбце device_type_canonical:
# ['desktop' 'mobile']
#
# Уникальные значения в столбце currency_code:
# ['kzt' 'rub']
#
# Уникальные значения в столбце event_type_main:
# ['выставки' 'другое' 'концерты' 'спорт' 'стендап' 'театр' 'ёлки']

# %%
df['region_name'].sort_values().unique()
# Out:
# array(['Белоярская область', 'Берестовский округ', 'Берёзовская область',
#        'Боровлянский край', 'Верховинская область', 'Верхозёрский край',
#        'Верхоречная область', 'Ветренский регион', 'Вишнёвский край',
#        'Глиногорская область', 'Голубевский округ',
#        'Горицветская область', 'Горноземский регион',
#        'Горностепной регион', 'Дальнеземская область',
#        'Дальнезорский край', 'Дубравная область', 'Залесский край',
#        'Заречная область', 'Зеленоградский округ', 'Златопольский округ',
#        'Золотоключевской край', 'Зоринский регион', 'Каменевский регион',
#        'Каменичская область', 'Каменноозёрный край', 'Каменноярский край',
#        'Каменополянский округ', 'Ключеводский округ',
#        'Кристаловская область', 'Кристальная область',
#        'Крутоводская область', 'Крутоводский регион', 'Лесноярский край',
#        'Лесодальний край', 'Лесополянская область', 'Лесостепной край',
# ...

# %%
df['city_name'].sort_values().unique()
# Out:
# array(['Айкольск', 'Айсуак', 'Акбастау', 'Акбасты', 'Акжолтау',
#        'Алтынкала', 'Алтынсай', 'Байкуль', 'Байсары', 'Байтерековск',
#        'Беловодск', 'Белоярск', 'Бережанка', 'Бережанск', 'Березиногорск',
#        'Березиноск', 'Березовцево', 'Берестовец', 'Берестяград',
#        'Берёзиново', 'Берёзовка', 'Берёзогорск', 'Берёзодальн',
#        'Берёзополье', 'Берёзореч', 'Берёзоречье', 'Бозарык', 'Боровлянск',
#        'Буркиттау', 'Бурьяново', 'Верховино', 'Верховка', 'Верхозолотск',
#        'Верхозорье', 'Верхоозёров', 'Ветеринск', 'Вишнёво',
#        'Вишнёвогорск', 'Вишнёводск', 'Водниково', 'Глиногорск',
#        'Глиногорь', 'Глиноград', 'Глинозолото', 'Глинозорь', 'Глинолес',
#        'Глинополин', 'Глинополье', 'Глинополянск', 'Глинореч', 'Глинянск',
#        'Голубевск', 'Голубино', 'Гореловск', 'Горицветск', 'Горноград',
#        'Горнодолинск', 'Горнолесье', 'Горнолуг', 'Горнополец',
#        'Горнополье', 'Горнополянск', 'Горнополяровск', 'Горнополёк',
# ...

# %%
df['service_name'].sort_values().unique()
# Out:
# array(['Crazy ticket!', 'Show_ticket', 'Билет по телефону',
#        'Билеты без проблем', 'Билеты в интернете', 'Билеты в руки',
#        'Быстробилет', 'Быстрый кассир', 'Весь в билетах', 'Восьмёрка',
#        'Вперёд!', 'Выступления.ру', 'Городской дом культуры',
#        'Дом культуры', 'Дырокол', 'За билетом!', 'Зе Бест!', 'КарандашРУ',
#        'Кино билет', 'Край билетов', 'Лимоны', 'Лови билет!',
#        'Лучшие билеты', 'Мир касс', 'Мой билет', 'Облачко', 'Прачечная',
#        'Радио ticket', 'Реестр', 'Росбилет', 'Тебе билет!', 'Телебилет',
#        'Тех билет', 'Цвет и билет', 'Шоу начинается!', 'Яблоко'],
#       dtype=object)

# %% [markdown]
# Все значения в категоральных данных уникальны. Среди данных нет категорий означающих пропуски в данных или отсутствие информации.

# %% [markdown]
# Нормализуем данные в категориальных столбцах.

# %%
df['service_name'] = df['service_name'].str.lower().str.strip()
df['region_name'] = df['region_name'].str.lower().str.strip()
df['city_name'] = df['city_name'].str.lower().str.strip()

# %% [markdown]
# ### Предварительный анализ числовых данных

# %% [markdown]
# Теперь посмотрим на данные выручки `revenue_rub` и количестве билетов в заказе `tickets_count`.

# %%
df['revenue_rub'].describe(percentiles=[0.25, 0.5, 0.75, 0.99])
# Out:
# count    290571.000000
# mean        555.585980
# std         875.528773
# min         -90.760000
# 25%         113.970000
# 50%         351.140000
# 75%         802.050000
# 99%        2628.420000
# max       81174.540000
# Name: revenue_rub, dtype: float64

# %% [markdown]
# Среднее значение существенно отличается медианой. Можно судить о наличии выбросов.\
# Посмотрим на распределение на графиках.

# %%
plt.figure(figsize=(12, 2))
df.boxplot(column='revenue_rub', vert=False)
plt.title('Распределение значений выручки')
plt.xlabel('Выручка')
plt.show()

# %%
plt.figure(figsize=(10, 5))
df['revenue_rub'].plot(
    kind="hist",
    alpha=0.75,
    bins=37,
    edgecolor="black",
)
plt.title('Распределение значений выручки')
plt.xlabel('Выручка')
plt.ylabel('Количество')
plt.grid()
plt.show()

# %% [markdown]
# Судя по графикам, распределение значений в столбце `revenue_rub` имеет много высоких выбросов после 99-го процентиля. На гистограмме виден явный хвост справа. Также имеются небольшие выбросы слева и присутствуют отрицательные значения.

# %% [markdown]
# Проанализируем распределение значений количества билетов в заказе.

# %%
df['tickets_count'].describe(percentiles=[0.25, 0.5, 0.75, 0.99])
# Out:
# count    290571.000000
# mean          2.754318
# std           1.170600
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# 99%           6.000000
# max          57.000000
# Name: tickets_count, dtype: float64

# %% [markdown]
# Распределение выглядит относительно симметричным. Среднее значение не сильно отличается от медианы.\
# Посмотрим на распределение на графиках.

# %%
plt.figure(figsize=(12, 2))
df.boxplot(column='tickets_count', vert=False)
plt.title('Распределение значений количества билетов в заказе')
plt.xlabel('Билеты в заказе')
plt.show()

# %%
plt.figure(figsize=(10, 5))
df['tickets_count'].plot(
    kind="hist",
    alpha=0.75,
    bins=37,
    edgecolor="black",
)
plt.title('Распределение значений количества билетов в заказе')
plt.xlabel('Билеты в заказе')
plt.ylabel('Количество')
plt.grid()
plt.show()

# %% [markdown]
# На графиках по количеству билетов в заказе также видим что имеется хвост справа. Судя по всему это были заказы для большого количества человек.

# %% [markdown]
# Значения выше 99-го процентиля можно считать выбросами. Можно отфильтровать данные и получить более достоверную статистику. Отфильтруем отрицательные значения и значения по 99-му перцентилю столбца `revenue_rub`.

# %%
df = df.loc[df['revenue_rub'] > 0]

# %%
percentile_99 = df['revenue_rub'].quantile(0.99)
df = df.loc[df['revenue_rub'] < percentile_99]

# %% [markdown]
# Посмотрим на статистические показатели после фильтрации.

# %%
df['revenue_rub'].describe()
# Out:
# count    281658.000000
# mean        527.540417
# std         509.075545
# min           0.020000
# 25%         122.610000
# 50%         358.020000
# 75%         796.360000
# max        2627.000000
# Name: revenue_rub, dtype: float64

# %% [markdown]
# После фильтрации стандартное отклонение уменьшилось с 875 до 509.

# %%
df['tickets_count'].describe()
# Out:
# count    281658.000000
# mean          2.743959
# std           1.157521
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# max          47.000000
# Name: tickets_count, dtype: float64

# %% [markdown]
# Данные сильно не поменялись. После фильтрации стандартное отклонение немного у меньшилось с 1.17 до 1.15.

# %% [markdown]
#  Определим объем отфильтрованных данных.

# %%
print(f'Количество данных до фильтрации - {temp.shape[0]}')
print(f'Количество данных после фильтрации - {df.shape[0]}')
print(f'Доля отфильтрованных данных - {round(100 - df.shape[0]/temp.shape[0] * 100, 2)}%')
# Out:
# Количество данных до фильтрации - 290611
# Количество данных после фильтрации - 281658
# Доля отфильтрованных данных - 3.08%

# %% [markdown]
# ### Промежуточные выводы после предобработки
#
# В результате предобработки данных были выполнены следующие действия:
#
# - Добавилен новый столбец `revenue_rub` с выручкой в рублях;
# - Оптимизирована разрядность в столбцах `order_id`, `tickets_count`, `days_since_prev` и `event_id`;
# - Нормализованы данные в категориальных столбцах `service_name`, `region_name` и `city_name`;
# - Найдено и удалены 40 неявных дубликатов.
# - Отфильтрованы отрицательные значения и значения по 99 перцентилю столбца `revenue_rub`.
# - Объем отфильтрованных данных 3%.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Предобработка данных <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b>
#
# * C задачей справились, предобработку провели!
#
#
# * Хорошо, что сопровождаешь графики заголовком и всеми необходимыми подписями - сразу понятно, что изображено на нем и как его читать!
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Относительно того, почему у нас есть пропуски - выше уже упомянула, причина в том, что это первый заказ пользователя, а не единственный.
#
#
# * Неполные дубликаты могут быть в том числе с разными `order_id`, например, если заказ пользователя задублировался в системе, был создан в нескольких экземплярах, при этом, возможно, даже с небольшой разницей во времен. Чтобы не искажать статистические расчеты, от таких наблюдений тоже лучше избавляться. Но для начала нужно проверить их начличие - для этого необходимо проверить, есть ли дубликаты на подвыборке без `order_id` и `days_since_prev`.
#
#
# * Для более полного анализа распределения числовых признаков стоит также изучать гистограмму. Для удобства анализа гистограмму для определенного признака стоит строить рядом с боксплотом, чтобы можно было сопоставлять информацию из них. Можно даже создать пользовательскую функцию, которая будет принимать на вход признак и выводить для него сразу два типа визуализации в одном графике ([пример](https://python-graph-gallery.com/24-histogram-with-a-boxplot-on-top-seaborn/)).
#
#
# * Было бы не лишним пояснить, почему мы решили отбросить выбросы в выручке? Почему решили не отбрасывать выбросы в количестве билетов? Откуда эти выбросы вообще могли взяться?
#
#
# * После того, как произвели фильтрацию, было бы неплохо также посмотреть, как поменялись значения и по другим показателям.
#
#
# * Было бы неплохо помимо доли также вывести количество до и после. Если выводим какие-то значения на печать, то в том числе стоит печатать и что это за значение, чтобы не приходилось разбираться в коде, чтобы это понять. Для красоты и удобства дробные значения при этом лучше округлять до знаков, которые могут представлять для нас интерес.
#
#
# </div>
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
# <b>Нужно доработать ❌:</b> Стоит также обратить внимание, что у нас есть отрицательные значения выручки. Возможно, это какие-то возвраты. По-хорошему, их тоже следовало бы исключить, чтобы не завышать количество валидных транзакций на пользователя. Перед этим не забываем проверить, какой процент данных потеряем, не критично ли это.
#
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; border-radius: 10px;  padding: 15px">
# <h3> Комментарий студента <a class="tocSkip"></h3>
#
# Постарался исправить.
#
# Если можешь поясни пожалуйста момент с фильтрацией. Выбросы мы видим и в данных по выручке и в данных по кол-ву билетов в заказе. Но, насколько я понял, данные по выручке нужно отфильтровать потому, что статистические данные показывают, что среднее сильно отличается от медианы, а статистические данные по количеству билетов в заказе в целом нормальные поэтому их не трогаем. Ну и часть максимальных выбросов по количеству так или иначе удалится при фильтрации данных по выручке. Или же решение об удалении надо было это вынести чисто логически глядя на то, что цифры аномально высокие? Но тогда и по кол-ву билетов в заказе максимальные значения выглядят высокими.
# </div>

# %% [markdown]
# ---
#
# ## Создание профиля пользователя
#
# В будущем отдел маркетинга планирует создать модель для прогнозирования возврата пользователей. Поэтому сейчас они просят вас построить агрегированные признаки, описывающие поведение и профиль каждого пользователя.
#
# ---
#
# **Задача 3.1.** Постройте профиль пользователя — для каждого пользователя найдите:
#
# - дату первого и последнего заказа;
# - устройство, с которого был сделан первый заказ;
# - регион, в котором был сделан первый заказ;
# - билетного партнёра, к которому обращались при первом заказе;
# - жанр первого посещённого мероприятия (используйте поле `event_type_main`);
# - общее количество заказов;
# - средняя выручка с одного заказа в рублях;
# - среднее количество билетов в заказе;
# - среднее время между заказами.
#
# После этого добавьте два бинарных признака:
#
# - `is_two` — совершил ли пользователь 2 и более заказа;
# - `is_five` — совершил ли пользователь 5 и более заказов.
#
# **Рекомендация:** перед тем как строить профиль, отсортируйте данные по времени совершения заказа.
#
# ---

# %% [markdown]
# Отсортируем данные в датафрейме `df` по времени совершения заказа.

# %%
df = df.sort_values('order_ts')

# %% [markdown]
# Создадим новый датафрейм `users_df` с уникальными пользователями и добаваим следующие колонки для каждого пользователя:
# - `first_order_dt` дата первого заказа;
# - `last_order_dt` дата последнего заказа;
# - `first_order_device` устройство, с которого был сделан первый заказ;
# - `first_order_region` регион, в котором был сделан первый заказ;
# - `first_order_service` билетный партнёр, к которому обращались при первом заказе;
# - `first_order_event` жанр первого посещённого мероприятия;
# - `total_orders` общее количество заказов;
# - `avg_revenue_rub` средняя выручка с одного заказа в рублях;
# - `avg_tickets_count` среднее количество билетов в заказе;
# - `avg_days_since_prev` среднее время между заказами;
# - `is_two` совершил ли пользователь 2 и более заказов;
# - `is_five` совершил ли пользователь 5 и более заказов.

# %%
users_df = df.groupby('user_id').agg(
    first_order_dt=('order_dt', 'min'),
    last_order_dt=('order_dt', 'max'),
    first_order_device=('device_type_canonical', 'first'),
    first_order_region=('region_name', 'first'),
    first_order_service=('service_name', 'first'),
    first_order_event=('event_type_main', 'first'),
    total_orders=('order_id', 'count'),
    avg_revenue_rub=('revenue_rub', lambda x: round(x.mean(), 2)),
    avg_tickets_count=('tickets_count', lambda x: round(x.mean(), 2)),
    avg_days_since_prev=('days_since_prev', lambda x: round(x.mean(), 2)),
).assign(
    is_two = lambda x: x['total_orders'] >= 2,
    is_five = lambda x: x['total_orders'] >= 5
).reset_index()
users_df.head()
# Out:
#            user_id first_order_dt last_order_dt first_order_device  \
# 0  0002849b70a3ce2     2024-08-20    2024-08-20             mobile
# 1  0005ca5e93f2cf4     2024-07-23    2024-10-06             mobile
# 2  000898990054619     2024-07-13    2024-10-23             mobile
# 3  00096d1f542ab2b     2024-08-15    2024-08-15            desktop
# 4  000a55a418c128c     2024-09-29    2024-10-15             mobile
#
#      first_order_region first_order_service first_order_event  total_orders  \
# 0    каменевский регион        край билетов             театр             1
# 1    каменевский регион           мой билет          выставки             2
# 2  североярская область         лови билет!            другое             3
# 3    каменевский регион        край билетов             театр             1
# 4      поленовский край       лучшие билеты             театр             2
#
#    avg_revenue_rub  avg_tickets_count  avg_days_since_prev  is_two  is_five
# ...

# %% [markdown]
# Добавим столбцы с двумя бинарными признакми. `is_two` - совершил ли пользователь 2 и более заказов и `is_five` - совершил ли пользователь 5 и более заказов.

# %%
# Создадим функцию для добавленния столбцов
def create_is_orders_count(row):
    is_2 = row['total_orders'] >= 2
    is_5 = row['total_orders'] >= 5
    
    return is_2, is_5

# %%
#users_df[['is_two', 'is_five']] = users_df.apply(create_is_orders_count, axis=1, result_type='expand')

# %%
#users_df.head()

# %% [markdown]
# Был создан датафрейм users_df с данными пользователей.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Создание профиля пользователя <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b>
#
# * Профиль составлен корректно!
#
#
# * Хорошо, что, ввиду использования агрегата `first`, не забываешь про сортировку заказов по времени!
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# Есть довольно удобный метод [assign](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.assign.html), позволяющий дополнять таблицу новыми рассчитанными столбцами.
#
# Тогда создание всего профиля можно будет записать красивым и удобным по структуре кодом.
#
# <details> <summary> <span style='color:blue' > Развернуть подробнее. </span> </summary>
#
# ```python
# profiles = (df
#         # В начале сортируем данные по дате совершения заказа, что найти первые признаки:
#         .sort_values(by='order_ts')
#         # Затем группируем по номеру пользователя и агрегируем данные:
#         .groupby('user_id')
#         .agg(
#             # Находим первую и последнюю даты заказа:
#             first_order_dt=('order_dt','min'),
#             last_order_dt=('order_dt','max'),
#             # Находим устройства, регион и название билетного партнера первого заказа:
#             first_device=('device_type_canonical','first'),
#             first_region_name=('region_name','first'),
#             first_service_name=('service_name','first'),
#             # Жанр первого посещённого мероприятия (event_type_main):
#             first_event_type=('event_type_main','first'),
#             # Подсчитваем количество заказов:
#             total_orders=('order_id','nunique'),
#             # Считаем статистику по заказам: средняя стоимость заказа, среднее количество билетов:
#             avg_revenue_rub=('revenue_rub','mean'),
#             avg_tickets_count=('tickets_count','mean'),
#             # Считаем среднее количество дней между покупками:
#             avg_days_since_prev=('days_since_prev','mean')
#         )
#         # Создаем два признака: совершил ли пользователь 2 / 5 и более заказов:
#         .assign(
#             is_two = lambda x: x['total_orders'] >= 2,
#             is_five = lambda x: x['total_orders'] >= 5
#         )
#         .reset_index()
# )
# ```
# </details>
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; border-radius: 10px;  padding: 15px">
# <h3> Комментарий студента <a class="tocSkip"></h3>
#
# Спасибо, переделал.
# </div>

# %% [markdown]
# ---
#
# **Задача 3.2.** Прежде чем проводить исследовательский анализ данных и делать выводы, важно понять, с какими данными вы работаете: насколько они репрезентативны и нет ли в них аномалий.
#
# Используя данные о профилях пользователей, рассчитайте:
#
# - общее число пользователей в выборке;
# - среднюю выручку с одного заказа;
# - долю пользователей, совершивших 2 и более заказа;
# - долю пользователей, совершивших 5 и более заказов.
#
# Также изучите статистические показатели:
#
# - по общему числу заказов;
# - по среднему числу билетов в заказе;
# - по среднему количеству дней между покупками.
#
# По результатам оцените данные: достаточно ли их по объёму, есть ли аномальные значения в данных о количестве заказов и среднем количестве билетов?
#
# Если вы найдёте аномальные значения, опишите их и примите обоснованное решение о том, как с ними поступить:
#
# - Оставить и учитывать их при анализе?
# - Отфильтровать данные по какому-то значению, например, по 95-му или 99-му перцентилю?
#
# Если вы проведёте фильтрацию, то вычислите объём отфильтрованных данных и выведите статистические показатели по обновлённому датасету.

# %% [markdown]
# Посчитаем общее число пользователей в выборке, среднюю выручку с одного заказа, долю пользователей, совершивших 2 и более заказа и долю пользователей, совершивших 5 и более заказов.

# %%
print(f"Общее количество пользователей - {users_df.shape[0]}")
print(f"Средняя выручка с одного заказа - {users_df['avg_revenue_rub'].mean().round(2)}")
print(f"Доля пользователей, совершивших 2 и более заказов - {round(users_df['is_two'].mean() * 100)}%")
print(f"Доля пользователей, совершивших 5 и более заказов - {round(users_df['is_five'].mean() * 100)}%")
# Out:
# Общее количество пользователей - 21694
# Средняя выручка с одного заказа - 550.85
# Доля пользователей, совершивших 2 и более заказов - 62%
# Доля пользователей, совершивших 5 и более заказов - 29%

# %% [markdown]
# Посмотрим на статистические данные общего числа заказов `total_orders`, среднего числа билетов в заказе `avg_tickets_count` и среднего количества дней между покупками `avg_days_since_prev`.

# %%
users_df[['total_orders', 'avg_tickets_count', 'avg_days_since_prev']].describe(percentiles=[0.25, 0.5, 0.75, 0.95, 0.99])
# Out:
#        total_orders  avg_tickets_count  avg_days_since_prev
# count  21694.000000       21694.000000         13447.000000
# mean      12.983221           2.745797            15.931180
# std      119.703141           0.914611            22.382849
# min        1.000000           1.000000             0.000000
# 25%        1.000000           2.000000             1.000000
# 50%        2.000000           2.750000             8.000000
# 75%        5.000000           3.090000            20.500000
# 95%       31.000000           4.000000            61.849998
# 99%      150.070000           5.000000           113.000000
# max     9981.000000          11.000000           148.000000

# %% [markdown]
# Среднее значение в столбце `total_orders` сильно выше медианы, можно судить о имеющихся высоких максимальных выбросах. Значения по 99-му перцентилю выглядят аномально высокими, возможно это результат действий перекупщиков, они могут искажать статистику. Будет логично отфильтровать значения по 99-му перцентилю.
#
# В данных `avg_tickets_count` разница между средним значением и медианой невелика, что указывает на симметричность распределения.
#
# Судя по значениям стобца `avg_days_since_prev` распределение имеет правостороннюю скошенность. Также видно, что количество непустых значений в столбце существенно меньше чем общее количество данных, это говорит о том что многие пользователи делают всего один заказ.

# %% [markdown]
# Отфильтруем значения `total_orders` по 99-му перцентилю.

# %%
# Cоздаем копию датасета до преобразования для возможности проверить сделанные изменения после предобработки
users_df_temp = users_df.copy() 
users_df_temp.shape[0]
# Out:
# 21694

# %%
# Отбросим выбросы
outliers = users_df['total_orders'].quantile(0.99)
users_df = users_df.loc[users_df['total_orders'] < outliers]
users_df.shape[0]
# Out:
# 21477

# %% [markdown]
# Вычислим объём отфильтрованных данных.

# %%
round(users_df.shape[0]/users_df_temp.shape[0], 2)
# Out:
# 0.99

# %% [markdown]
# Был отфильтрован 1% данных.

# %% [markdown]
# Посмотрим показатели обновлённого датасета.

# %%
print(f"Общее количество пользователей - {users_df.shape[0]}")
print(f"Средняя выручка с одного заказа - {users_df['avg_revenue_rub'].mean().round(2)}")
print(f"Доля пользователей, совершивших 2 и более заказов - {round(users_df['is_two'].mean() * 100)}%")
print(f"Доля пользователей, совершивших 5 и более заказов - {round(users_df['is_five'].mean() * 100)}%")
# Out:
# Общее количество пользователей - 21477
# Средняя выручка с одного заказа - 551.12
# Доля пользователей, совершивших 2 и более заказов - 61%
# Доля пользователей, совершивших 5 и более заказов - 28%

# %%
users_df[['total_orders', 'avg_tickets_count', 'avg_days_since_prev']].describe(percentiles=[0.25, 0.5, 0.75, 0.95, 0.99])
# Out:
#        total_orders  avg_tickets_count  avg_days_since_prev
# count  21477.000000       21477.000000         13230.000000
# mean       6.400428           2.745971            16.184908
# std       13.965541           0.919079            22.477076
# min        1.000000           1.000000             0.000000
# 25%        1.000000           2.000000             1.332500
# 50%        2.000000           2.750000             8.400000
# 75%        5.000000           3.110000            21.000000
# 95%       26.000000           4.000000            62.000000
# 99%       77.240000           5.000000           113.000000
# max      150.000000          11.000000           148.000000

# %% [markdown]
# После удаления выбросов стандартное отклонение в столбце `total_orders` стало меньше: было **119.7**, а стало **13.9**. Распределение данных стало намного компактнее, что улучшает качество анализа.
#
# Данные по среднему числу билетов в заказе не изменились.
#
# Данные по среднему количеству дней между покупками не сильно поменялись.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ пользовательских профилей <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> Здесь тоже все супер, выполнены все необходимые шаги!
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Обрати внимание, что относительно пользователей с как минимум 2 и как минимум 5 заказами предлагалось посмотреть долю, все-таки это более удобный вариант оценки, чем самостоятельное прикидывание доли относительно общего количества.
#
#
# * Повторяющиеся действия лучше реализовывать через цикл, чтобы снизить риск человеческого фактора, и чтобы код был более удобен для восприятия. Стат распределение по числовым признакам можно было бы вывести разом одним `describe`.
#
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; border-radius: 10px;  padding: 15px">
# <h3> Комментарий студента <a class="tocSkip"></h3>
#
# Поправил.
# </div>

# %% [markdown]
# ---
#
# ## Исследовательский анализ данных
#
# Следующий этап — исследование признаков, влияющих на возврат пользователей, то есть на совершение повторного заказа. Для этого используйте профили пользователей.

# %% [markdown]
# ### Исследование признаков первого заказа и их связи с возвращением на платформу
#
# Исследуйте признаки, описывающие первый заказ пользователя, и выясните, влияют ли они на вероятность возвращения пользователя.
#
# ---
#
# **Задача 4.1.1.** Изучите распределение пользователей по признакам.
#
# - Сгруппируйте пользователей:
#     - по типу их первого мероприятия;
#     - по типу устройства, с которого совершена первая покупка;
#     - по региону проведения мероприятия из первого заказа;
#     - по билетному оператору, продавшему билеты на первый заказ.
# - Подсчитайте общее количество пользователей в каждом сегменте и их долю в разрезе каждого признака. Сегмент — это группа пользователей, объединённых определённым признаком, то есть объединённые принадлежностью к категории. Например, все клиенты, сделавшие первый заказ с мобильного телефона, — это сегмент.
# - Ответьте на вопрос: равномерно ли распределены пользователи по сегментам или есть выраженные «точки входа» — сегменты с наибольшим числом пользователей?
#
# ---

# %% [markdown]
# Посмотрим на распределение пользователей по значениям в столбцах с данными первого заказа.

# %%
users_df["first_order_event"].value_counts()
# Out:
# концерты    9598
# другое      5224
# театр       4260
# стендап     1118
# спорт        765
# выставки     415
# ёлки          97
# Name: first_order_event, dtype: int64

# %%
plt.figure(figsize=(10, 5))
users_df['first_order_event'].value_counts(normalize=True).plot(
               kind='bar',
               rot=0,
               legend=False,
               title=f'Распределение клиентов в зависимости от типа первого мероприятия'
)
plt.xlabel('Тип мероприятия')
plt.ylabel('Доля пользователей')
plt.grid()
plt.show()

# %% [markdown]
# Чаще всего в первый раз пользователи покупают билеты на концерты, таких пользователей 44%, на втором месте мероприятия из категории "другое" - 25%. Меньше всего в первый раз берут билет на ёлку, таких пользователей менее 1%.

# %%
users_df["first_order_device"].value_counts()
# Out:
# mobile     17799
# desktop     3678
# Name: first_order_device, dtype: int64

# %%
plt.figure(figsize=(10, 5))
users_df['first_order_device'].value_counts(normalize=True).plot(
               kind='bar',
               rot=0,
               legend=False,
               title=f'Распределение клиентов в зависимости от устройства с которого сделан первый заказ'
)
plt.xlabel('Тип устройства')
plt.ylabel('Доля пользователей')
plt.grid()
plt.show()

# %% [markdown]
# Пользователи чаще всего делают первый заказ с мобильных устройств, таких пользователей - 83%, остальные используют компьютер. Данное соотношение в принципе не удивительно, интернетом пользуются больше всего на мобильных устройствах.

# %%
users_df["first_order_region"].value_counts()
# Out:
# каменевский регион          6975
# североярская область        3785
# широковская область         1234
# озернинский край             678
# малиновоярский округ         527
#                             ...
# светолесский край              2
# тихогорская область            2
# яснопольский округ             1
# верхозёрский край              1
# сосноводолинская область       1
# Name: first_order_region, Length: 81, dtype: int64

# %%
plt.figure(figsize=(10, 5))
users_df['first_order_region'].value_counts(normalize=True).head(10).plot(
               kind='barh',
               rot=0,
               legend=False,
               title=f'Распределение клиентов в зависимости от региона в котором сделан первый заказ'
)
plt.xlabel('Доля пользователей')
plt.ylabel('Регион')
plt.grid()
plt.show()

# %% [markdown]
# Больше всего пользователей совершавших первый заказ в Каменевском регионе - 33%, Североярской области - 17% и Широковской области - 6%. Можно предположить что эти регионы в целом больше остальных по количеству людей.

# %%
users_df["first_order_service"].value_counts()
# Out:
# билеты без проблем        4968
# мой билет                 2985
# лови билет!               2802
# билеты в руки             2549
# облачко                   2198
# весь в билетах            1291
# лучшие билеты             1183
# прачечная                  586
# край билетов               460
# дом культуры               358
# яблоко                     320
# тебе билет!                310
# городской дом культуры     218
# мир касс                   213
# за билетом!                204
# быстробилет                165
# show_ticket                158
# выступления.ру              95
# восьмёрка                   86
# быстрый кассир              61
# crazy ticket!               46
# росбилет                    40
# радио ticket                36
# реестр                      33
# телебилет                   27
# цвет и билет                23
# шоу начинается!             19
# карандашру                  15
# кино билет                   9
# вперёд!                      7
# ...

# %%
plt.figure(figsize=(10, 5))
users_df['first_order_service'].value_counts(normalize=True).head(10).plot(
               kind='barh',
               rot=0,
               legend=False,
               title=f'Распределение клиентов в зависимости от сервиса в котором сделан первый заказ'
)
plt.xlabel('Доля пользователей')
plt.ylabel('Сервис')
plt.grid()
plt.show()

# %% [markdown]
# Чаще всего пользовати делают первый заказ через сервис "Билеты без проблем" - 24%. Судя по всему этот сервис наиболее популярен среди остальных.

# %% [markdown]
# В целом по всем проанализированным признакам данные распределены неравномерно. По каждому признаку имеются ярко выраженные сегменты с большим количество пользователей.

# %% [markdown]
# ---
#
# **Задача 4.1.2.** Проанализируйте возвраты пользователей:
#
# - Для каждого сегмента вычислите долю пользователей, совершивших два и более заказа.
# - Визуализируйте результат подходящим графиком. Если сегментов слишком много, то поместите на график только 10 сегментов с наибольшим количеством пользователей. Такое возможно с сегментами по региону и по билетному оператору.
# - Ответьте на вопросы:
#     - Какие сегменты пользователей чаще возвращаются на Яндекс Афишу?
#     - Наблюдаются ли успешные «точки входа» — такие сегменты, в которых пользователи чаще совершают повторный заказ, чем в среднем по выборке?
#
# При интерпретации результатов учитывайте размер сегментов: если в сегменте мало пользователей (например, десятки), то доли могут быть нестабильными и недостоверными, то есть показывать широкую вариацию значений.
#
# ---

# %%
grouped_by_first_order_event = users_df.groupby('first_order_event')['is_two'].mean().sort_values(ascending=False)
grouped_by_first_order_event
# Out:
# first_order_event
# выставки    0.643373
# театр       0.634977
# концерты    0.617733
# стендап     0.609123
# другое      0.594372
# ёлки        0.567010
# спорт       0.549020
# Name: is_two, dtype: float64

# %%
first_order_event_mean_value = grouped_by_first_order_event.mean()

# %%
grouped_by_first_order_event.plot(
    kind='bar',
    rot=0,
    legend=True,
    title=f'Доля клиентов совершивших 2 и более заказа в зависимости от типа первого мероприятия',
    figsize=(12, 7)
)
plt.xlabel('Тип мероприятия')
plt.ylabel('Доля пользователей')
plt.axhline(y=first_order_event_mean_value, color='red', linestyle='--', label='Среднее значение')
plt.grid()
plt.show()

# %% [markdown]
# Чаще всего возвращаются пользователи делавшие первый заказ на выставки (64%), театр (64%) и концерт (62%).

# %%
grouped_by_first_order_device = users_df.groupby('first_order_device')['is_two'].mean().sort_values(ascending=False)
grouped_by_first_order_device
# Out:
# first_order_device
# desktop    0.636215
# mobile     0.608012
# Name: is_two, dtype: float64

# %%
first_order_device_mean_value = grouped_by_first_order_device.mean()

# %%
grouped_by_first_order_device.plot(
    kind='bar',
    rot=0,
    legend=True,
    title=f'Доля клиентов совершивших 2 и более заказа в зависимости от устройства с которого сделан первый заказ',
    figsize=(12, 7)
)
plt.xlabel('Тип устройства')
plt.ylabel('Доля пользователей')
plt.axhline(y=first_order_device_mean_value, color='red', linestyle='--', label='Среднее значение')
plt.grid()
plt.show()

# %% [markdown]
# Чаще всего возвращаются пользователи делавшие первый заказ с компьютера. Доля таких пользователй 64%. Это не сильно отличается от пользователей делавших первый заказ с мобильных устройств, там доля таких пользователей - 61%.

# %% [markdown]
# Определим топ-10 регионов по общему количеству пользователей.

# %%
top_regions = users_df['first_order_region'].value_counts().head(10)
print(f'Топ 10 регионов по количеству пользователей это {round(top_regions.sum()/users_df.shape[0] * 100)}% от общего количества.')
# Out:
# Топ 10 регионов по количеству пользователей это 72% от общего количества.

# %%
grouped_by_first_region = users_df[users_df['first_order_region'].isin(top_regions.index)].groupby('first_order_region')['is_two'].mean().sort_values(ascending=False)
grouped_by_first_region
# Out:
# first_order_region
# шанырский регион        0.694624
# светополянский округ    0.657267
# широковская область     0.645057
# североярская область    0.640687
# речиновская область     0.638202
# каменевский регион      0.619211
# травяная область        0.616052
# яблоневская область     0.593674
# малиновоярский округ    0.557875
# озернинский край        0.551622
# Name: is_two, dtype: float64

# %%
first_order_region_mean_value = grouped_by_first_region.mean()

# %%
grouped_by_first_region.plot(
    kind='barh',
    rot=0,
    legend=True,
    title=f'Доля клиентов совершивших 2 и более заказов в зависимости от региона в котором сделан первый заказ',
    figsize=(12, 10)
)
plt.xlabel('Доля пользователей')
plt.ylabel('Регион')
plt.axvline(x=first_order_region_mean_value, color='red', linestyle='--', label='Среднее значение')
plt.grid()
plt.show()

# %% [markdown]
# Чаще всего возвращаются пользователи делавшие первый заказ из следующих регионов: Шанырский регион (70%), Светополянский округ (66%) и Широковская область (65%).

# %% [markdown]
# Определим топ-10 сервисов по общему количеству пользователей.

# %%
top_services = users_df['first_order_service'].value_counts().head(10)
print(f'Топ 10 сервисов по количеству пользователей это {round(top_services.sum()/users_df.shape[0] * 100)}% от общего количества.')
# Out:
# Топ 10 сервисов по количеству пользователей это 90% от общего количества.

# %%
grouped_by_first_service = users_df[users_df['first_order_service'].isin(top_services.index)].groupby('first_order_service')['is_two'].mean().sort_values(ascending=False)
grouped_by_first_service
# Out:
# first_order_service
# край билетов          0.654348
# дом культуры          0.648045
# билеты в руки         0.629659
# весь в билетах        0.628970
# прачечная             0.626280
# лучшие билеты         0.614539
# облачко               0.613740
# лови билет!           0.611349
# мой билет             0.607370
# билеты без проблем    0.597625
# Name: is_two, dtype: float64

# %%
first_order_service_mean_value = grouped_by_first_service.mean()

# %%
grouped_by_first_service.plot(
    kind='barh',
    rot=0,
    legend=True,
    title=f'Доля клиентов совершивших 2 и более заказов в зависимости от сервиса в котором сделан первый заказ',
    figsize=(12, 10)
)
plt.xlabel('Доля пользователей')
plt.ylabel('Сервис')
plt.axvline(x=first_order_service_mean_value, color='red', linestyle='--', label='Среднее значение')
plt.grid()
plt.show()

# %% [markdown]
# Чаще всего возвращаются пользователи делавшие первый заказ с помощью следующих сервисов: край билетов (65%), дом культуры (65%), билеты в руки (63%), весь в билетах (63%) и прачечная (63%).

# %% [markdown]
# ---
#
# **Задача 4.1.3.** Опираясь на выводы из задач выше, проверьте продуктовые гипотезы:
#
# - **Гипотеза 1.** Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
# - **Гипотеза 2.** В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.
#
# ---

# %% [markdown]
# Проверим первую гипотезу.

# %%
print(f"Среднее время между заказами у пользователей которые совершили первый заказ на спортивные мероприятия - {round(users_df[users_df['first_order_event'] == 'спорт']['avg_days_since_prev'].mean())} дней")
# Out:
# Среднее время между заказами у пользователей которые совершили первый заказ на спортивные мероприятия - 9 дней

# %%
print(f"Среднее время между заказами у пользователей которые совершили первый заказ на концерты - {round(users_df[users_df['first_order_event'] == 'концерты']['avg_days_since_prev'].mean())} дней")
# Out:
# Среднее время между заказами у пользователей которые совершили первый заказ на концерты - 17 дней

# %% [markdown]
# Гипотеза 1 подтверждается. Среднее время между заказами у пользователей которые совершили первый заказ на спортивные мероприятия - 9 дней, у пользователей которые совершили первый заказ на концерты - 17 дней.

# %% [markdown]
# Гипотеза 2 не подтверждается. Доля повторных заказов выше в Шанырском регионе (70%), где доля пользователей примерно 2% от общего количества.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ сегментов пользователей <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> Хорошо, что грамотно оформляешь графики, со всеми подписями и заголовком.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
# <b>Нужно доработать ❌:</b>
#
# Обрати внимание, что во второй части данного этапе вместо доли вернувшихся клиентов в каждом сегменте ты считаешь, как распределились сегменты между вернувшимися клиентами, что не то же самое. Чтобы посчитать именно долю вернувшихся, необходимо сгруппировать данный по сегментам и посчитать среднее от `is_two`. Выводы, соответственно, тоже нужно будет скорректировать, они поменяются.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
#
# * В случае вывода неполного набора сегментов стоит указать, какой процент от выборки они составляют, чтобы было понимание, насколько большая часть данных осталась за пределами нашего обзора.
#
#
# * На графиках сегменты было бы логичнее отсортировать от большего к меньшему, поскольку большие сегменты представляют для нас больший интерес.
#
#
# * Также было бы неплохо добавить на графики линию среднего значения, чтобы было удобно сравнивать, какие сегменты и насколько отличаются от общего показателя по выборке. Это можно сделать с помощью `plt.axvline`, потребуется также добавить легенду.
#
#
# * Поскольку код идентичный, было бы лучше зациклить его выполнение, а после уже сконцентрироваться на выводах.
#
#
# * В выводах по анализу сегментов было бы неплохо также попробовать предположить, почему мы могли получить то или иное распределение по сегментам. Это может быть полезно в плане развития стратегий по привлечению новых пользователей.
#
#
# * Относительно анализа по гипотезам. Во-первых, было бы не лишним в выводах указывать конкретные значение, относительно которых ты строишь суждения. Во-вторых, важно иметь в виду, что сегменты у нас различаются по численности (иногда достаточно существенно, как в случае регионов). В менее популярных сегментах 1 дополнительный пользователь имеет больший вес, а потому показатель возвращаемости у таких категорий больше подвержен колебаниям, менее стабилен. Поэтому в менее представленных сегментах важно делать какую-то поправку на количество - например, отобрать только те, где хотя бы 100 пользователей.
#
#     Но вообще, чтобы наверняка убедиться в том, что возвращаемость в неполпуляных группах ниже, и это не случайное колебание, следует провести статистический тест, оценить значимость различий. Это будет изучаться в дальнейшем на курсе.
#
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; border-radius: 10px;  padding: 15px">
# <h3> Комментарий студента <a class="tocSkip"></h3>
#
# Здесь тоже постарался все исправить.
# </div>

# %% [markdown]
# ---
#
# ### Исследование поведения пользователей через показатели выручки и состава заказа
#
# Изучите количественные характеристики заказов пользователей, чтобы узнать среднюю выручку сервиса с заказа и количество билетов, которое пользователи обычно покупают.
#
# Эти метрики важны не только для оценки выручки, но и для оценки вовлечённости пользователей. Возможно, пользователи с более крупными и дорогими заказами более заинтересованы в сервисе и поэтому чаще возвращаются.
#
# ---
#
# **Задача 4.2.1.** Проследите связь между средней выручкой сервиса с заказа и повторными заказами.
#
# - Постройте сравнительные гистограммы распределения средней выручки с билета (`avg_revenue_rub`):
#     - для пользователей, совершивших один заказ;
#     - для вернувшихся пользователей, совершивших 2 и более заказа.
# - Ответьте на вопросы:
#     - В каких диапазонах средней выручки концентрируются пользователи из каждой группы?
#     - Есть ли различия между группами?
#
# Текст на сером фоне:
#
# **Рекомендация:**
#
# 1. Используйте одинаковые интервалы (`bins`) и прозрачность (`alpha`), чтобы визуально сопоставить распределения.
# 2. Задайте параметру `density` значение `True`, чтобы сравнивать форму распределений, даже если число пользователей в группах отличается.
#
# ---

# %% [markdown]
# Построим сравнительную гистограмму распределения средней выручки с билета для пользователей, совершивших один заказ и для вернувшихся пользователей.

# %%
min_avg_revenue_rub_value = round(users_df['avg_revenue_rub'].min())
max_avg_revenue_rub_value = round(users_df['avg_revenue_rub'].max())
plt.figure(figsize=(10, 5))
for i in users_df['is_two'].unique():
    users_df.loc[users_df['is_two'] == i, 'avg_revenue_rub'].plot(
                    kind='hist',
                    bins = range(min_avg_revenue_rub_value, max_avg_revenue_rub_value+1, 50),
                    alpha=0.5,
                    rot=0,
                    density=True,
                    label=f'{i}',
                    legend=True
    )
plt.title('Распределения средней выручки с билета')
plt.xlabel('Средняя выручка')
plt.ylabel('Плотность вероятности')
plt.grid()
plt.show()

# %% [markdown]
# Пользователи совершившие один заказ больше всего сконцентрированы в районе минимальных значений средней выручки и примерно до 200. Имеется отчетливый всплеск в значениях близких к 0. Вернувшиеся пользователи имеют пик в значении 500. Распределие обоих групп явно отличается. На графике пользователей сделавших один заказ наблюдается правосторонняя асимметрия — правый хвост распределения явно вытянут, график с вернувшимися пользователями имеет более симметричное распределение. Стоит отметить что пользователей сделавших один заказ немного больше чем вернувшихся в значениях больше 1000.

# %% [markdown]
# ---
#
# **Задача 4.2.2.** Сравните распределение по средней выручке с заказа в двух группах пользователей:
#
# - совершившие 2–4 заказа;
# - совершившие 5 и более заказов.
#
# Ответьте на вопрос: есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?
#
# ---

# %% [markdown]
# Построим сравнительную гистограмму распределения средней выручки с заказа в группах пользователей совершивших 2-4 заказа и более 5 заказов.

# %%
plt.figure(figsize=(10, 5))
users_df[(users_df['is_two'] == True) & (users_df['is_five'] != True)]['avg_revenue_rub'].plot(
    kind="hist",
    alpha=0.5,
    bins = range(min_avg_revenue_rub_value, max_avg_revenue_rub_value+1, 50),
    label='2-4 заказа',
    legend=True,
    density=True
)
users_df[users_df['is_five'] == True]['avg_revenue_rub'].plot(
    kind="hist",
    alpha=0.5,
    bins = range(min_avg_revenue_rub_value, max_avg_revenue_rub_value+1, 50),
    label='более 5 заказов',
    legend=True,
    density=True
)
plt.title('Распределение по средней выручке с заказа в группах пользователей совершивших 2-4 заказа и более 5 заказов')
plt.xlabel('Средняя выручка')
plt.ylabel('Плотность вероятности')
plt.grid()
plt.show()

# %% [markdown]
# Распределие обоих групп отличается. График пользователей сделавших 2-4 заказа имеет правостороннюю асимметрию. График с пользователями сделавших более 5 заказов имеет более симметричное распределение и имеет пиковое значение в районне 500. Пользователей сделавших 2-4 заказа больше в значениях до 300 и выше 800. Можно предположить что пользователи делающие более 5 заказов, делают регулярные заказы на определенные мероприятия со средним чеком в районе 500 рублей.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ взаимосвязи средней выручки и числа заказов <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b>
#
# * С этой задачей справились!
#
#
# * Плюсик за грамотное оформление графиков - заголовок, подписи осей, легенда, поправка на размер выборки (`density`). По выводом тоже все верно подмечено!
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Чтобы удобно было сопоставлять доли пользователей по диапазонам цен, можно настроить единый размер бинов (`bins = 50` фиксирует количество бинов, но размер между сегментами будет отличаться, поскольку диапазон значений у них разный). Для этого в `bins` можно передать границы для формирования бинов с шагом: `bins = range(min_value, max_value+1, 50)`, максимальное и минимальное значения при этом определяем на всей выборке, а не отдельно для каждого сегмента.
#
#
# * Было бы неплохо сделать какой-то резюмирующий вывод, что мы в итоге пронаблюдали, какие пользователи превосходят по выручке. Также было бы неплохо сформулировать предположение, почему мы можем наблюдать именно такой результат.
#
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; border-radius: 10px;  padding: 15px">
# <h3> Комментарий студента <a class="tocSkip"></h3>
#
# Подкорректировал графики и дополнил вывод.
# </div>

# %% [markdown]
# ---
#
# **Задача 4.2.3.** Проанализируйте влияние среднего количества билетов в заказе на вероятность повторной покупки.
#
# - Изучите распределение пользователей по среднему количеству билетов в заказе (`avg_tickets_count`) и опишите основные наблюдения.
# - Разделите пользователей на несколько сегментов по среднему количеству билетов в заказе:
#     - от 1 до 2 билетов;
#     - от 2 до 3 билетов;
#     - от 3 до 5 билетов;
#     - от 5 и более билетов.
# - Для каждого сегмента подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы.
# - Ответьте на вопросы:
#     - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#     - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?
#
# ---

# %% [markdown]
# Построим сравнительную гистограмму распределения пользователей по среднему количеству билетов в заказе.

# %%
plt.figure(figsize=(10, 5))
users_df['avg_tickets_count'].plot(
    kind="hist",
    alpha=0.75,
    bins=37,
    edgecolor="black"
)
plt.title('Распределение пользователей по среднему количеству билетов в заказе')
plt.xlabel('Количеству билетов в заказе')
plt.ylabel('Количество пользователей')
plt.grid()
plt.show()

# %% [markdown]
# Судя по графику чаще всего полльзователи покупают 3 или 2 билета.

# %% [markdown]
# Разделим пользователей на несколько сегментов по среднему количеству билетов в заказе.

# %%
users_df['avg_tickets_count_segment'] = pd.cut(
    users_df['avg_tickets_count'],
    bins=[1, 2, 3, 5, 100],
    labels=["от 1 до 2 билетов", "от 2 до 3 билетов", "от 3 до 5 билетов", "от 5 и более билетов"],
    right=False
)
users_df.head()
# Out:
#            user_id first_order_dt last_order_dt first_order_device  \
# 0  0002849b70a3ce2     2024-08-20    2024-08-20             mobile
# 1  0005ca5e93f2cf4     2024-07-23    2024-10-06             mobile
# 2  000898990054619     2024-07-13    2024-10-23             mobile
# 3  00096d1f542ab2b     2024-08-15    2024-08-15            desktop
# 4  000a55a418c128c     2024-09-29    2024-10-15             mobile
#
#      first_order_region first_order_service first_order_event  total_orders  \
# 0    каменевский регион        край билетов             театр             1
# 1    каменевский регион           мой билет          выставки             2
# 2  североярская область         лови билет!            другое             3
# 3    каменевский регион        край билетов             театр             1
# 4      поленовский край       лучшие билеты             театр             2
#
#    avg_revenue_rub  avg_tickets_count  avg_days_since_prev  is_two  is_five  \
# ...

# %% [markdown]
# Посчитаем общее число пользователей и долю пользователей, совершивших повторные заказы для каждого сегмента.

# %%
for segment in users_df['avg_tickets_count_segment'].unique():
    segment_users = users_df[users_df['avg_tickets_count_segment'] == segment] 
    print(f'Общее число пользователей заказывающих в среднем {segment} - {segment_users.shape[0]}')
    print(f'Доля пользователей совершивших повторные заказы среди них - {round(segment_users["is_two"].mean(), 2)}')
    print()
# Out:
# Общее число пользователей заказывающих в среднем от 3 до 5 билетов - 9019
# Доля пользователей совершивших повторные заказы среди них - 0.54
#
# Общее число пользователей заказывающих в среднем от 2 до 3 билетов - 9408
# Доля пользователей совершивших повторные заказы среди них - 0.73
#
# Общее число пользователей заказывающих в среднем от 1 до 2 билетов - 2393
# Доля пользователей совершивших повторные заказы среди них - 0.51
#
# Общее число пользователей заказывающих в среднем от 5 и более билетов - 657
# Доля пользователей совершивших повторные заказы среди них - 0.19

# %%
grouped_by_avg_tickets_count = users_df.groupby('avg_tickets_count_segment')['is_two'].value_counts().unstack(fill_value=0)

# %%
avg_tickets_count_mean_value = grouped_by_avg_tickets_count.unstack().mean()

# %%
grouped_by_avg_tickets_count.plot(
    kind='bar',
    rot=0,
    legend=True,
    title=f'Количество клиентов совершивших 1 заказ и вернувшихся в зависимости от среднего количества билетов в заказе',
    figsize=(12, 7)
)
plt.xlabel('Среднее количество билетов в заказе')
plt.ylabel('Количество пользователей')
plt.axhline(y=avg_tickets_count_mean_value, color='red', linestyle='--', label='Среднее значение')
plt.grid()
plt.show()

# %% [markdown]
# Пользователи распределены по сегментам неравномерно. Наибольшая концентрация наблюдается в сегментах где пользователи покупают в среднем от 2 до 3 и от 3 до 5 билетов. В группе пользователей покупающих от 2 до 3 билетов наблюдается высокое значение повторных покупок - 74%. Это можно объяснить тем что скорее всего на мероприятия приходят вдвоем или с детьми. В группе пользователей покупающих более 5 билетов наименьшее значение повторных покупок - 19%. В остальных сегментах примерно половина пользователей совершает повторные покупки.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ взаимосвязи количества билетов в заказе и возвращаемости <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b>
#
# * Здесь тоже все корректно посчитано! Выводы верные!
#
#
# * Здорово, что используешь удобный метод `pd.cut` и корректно настраиваешь параметры, чтобы включалась левая граница и исключалась правая.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Чтобы посчитать долю вернувшихся, можно было бы провести группировку и взять среднее по `is_two`.
#
#
# * Было бы неплохо для наглядности построить график с отображением линии среднего значения, чтобы четко было видно, какой сегмент и насколько отклоняется.
#
#
# * В выводах было бы неплохо предположить, почему получились именно такие результаты. Опять же, это может быть полезно в плане развития стратегий по привлечению пользователей.
#
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; border-radius: 10px;  padding: 15px">
# <h3> Комментарий студента <a class="tocSkip"></h3>
#
# Добавил график, но не очень понял среднее чего хотелось бы видеть) Вывел среднее по общему количеству в сегментах.
# </div>

# %% [markdown]
# ---
#
# ### Исследование временных характеристик первого заказа и их влияния на повторные покупки
#
# Изучите временные параметры, связанные с первым заказом пользователей:
#
# - день недели первой покупки;
# - время с момента первой покупки — лайфтайм;
# - средний интервал между покупками пользователей с повторными заказами.
#
# ---
#
# **Задача 4.3.1.** Проанализируйте, как день недели, в которой была совершена первая покупка, влияет на поведение пользователей.
#
# - По данным даты первого заказа выделите день недели.
# - Для каждого дня недели подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы. Результаты визуализируйте.
# - Ответьте на вопрос: влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?
#
# ---

# %% [markdown]
# Выделим день недели первого заказа для каждого пользователя.

# %%
def categorize_first_order_day(row):
    return row['first_order_dt'].day_of_week

#users_df['first_order_weekday'] = users_df.apply(categorize_first_order_day, axis=1)

# %%
users_df['first_order_weekday'] = users_df['first_order_dt'].dt.day_name()

# %%
users_df.head()
# Out:
#            user_id first_order_dt last_order_dt first_order_device  \
# 0  0002849b70a3ce2     2024-08-20    2024-08-20             mobile
# 1  0005ca5e93f2cf4     2024-07-23    2024-10-06             mobile
# 2  000898990054619     2024-07-13    2024-10-23             mobile
# 3  00096d1f542ab2b     2024-08-15    2024-08-15            desktop
# 4  000a55a418c128c     2024-09-29    2024-10-15             mobile
#
#      first_order_region first_order_service first_order_event  total_orders  \
# 0    каменевский регион        край билетов             театр             1
# 1    каменевский регион           мой билет          выставки             2
# 2  североярская область         лови билет!            другое             3
# 3    каменевский регион        край билетов             театр             1
# 4      поленовский край       лучшие билеты             театр             2
#
#    avg_revenue_rub  avg_tickets_count  avg_days_since_prev  is_two  is_five  \
# ...

# %% [markdown]
# Посчитаем общее число пользователей и долю пользователей, совершивших повторные заказы для каждого дня недели первого заказа.

# %%
for day in users_df['first_order_weekday'].sort_values().unique():
    users = users_df[users_df['first_order_weekday'] == day]
    print(f'Количество пользователей совершивших первый заказ в {day} - {users.shape[0]}')
    print(f'Доля пользователей среди них сделавших повторные покупки {round(users["is_two"].mean(), 2)}')
    print()
# Out:
# Количество пользователей совершивших первый заказ в Friday - 3231
# Доля пользователей среди них сделавших повторные покупки 0.6
#
# Количество пользователей совершивших первый заказ в Monday - 2902
# Доля пользователей среди них сделавших повторные покупки 0.63
#
# Количество пользователей совершивших первый заказ в Saturday - 3293
# Доля пользователей среди них сделавших повторные покупки 0.63
#
# Количество пользователей совершивших первый заказ в Sunday - 2757
# Доля пользователей среди них сделавших повторные покупки 0.6
#
# Количество пользователей совершивших первый заказ в Thursday - 3099
# Доля пользователей среди них сделавших повторные покупки 0.6
#
# Количество пользователей совершивших первый заказ в Tuesday - 3147
# Доля пользователей среди них сделавших повторные покупки 0.62
#
# Количество пользователей совершивших первый заказ в Wednesday - 3048
# Доля пользователей среди них сделавших повторные покупки 0.62

# %% [markdown]
# Больше всего первый заказ пользователи делали в субботу, меньше всего в воскресенье. В целом значения распределены равномерно. Доля пользователей совершивших повторые заказы в целом не меняется в зависимости от для неделеи первого заказа и равна ~ 61%. Можно сделать вывод что день недели первого заказа не влияет на возврат клиента. Распределение можно объяснить тем что клиенты возможно в большей степени покупают билеты на мероприятия незадолго до начала выходных, т.е. четверг, пятницу или в начале выходных в субботу.

# %% [markdown]
# Посмотрим на распределение на графиках.

# %%
users_df.groupby('first_order_weekday')['is_two'].mean().plot(
    kind='bar',
    rot=0,
    title=f'Доля вернувшихся пользователей в зависимости от дня недели первого заказа',
    figsize=(10, 5)
)
plt.xlabel('Дни недели')
plt.ylabel('Доля пользователей')
plt.grid()
plt.show()

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ возвращаемости по дням недели  <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> Здесь тоже все супер! Различия по дням недели все же наблюдаеются, хотя и не очень заметные. Чтобы судить более однозначно, было бы неплохо сопроводить сравнение оценкой стат. значимости. Это будет изучаться далее на курсе.
#
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Чтобы определить день недели в каждой строке, можно обойтись без цикличного `apply`. Для этого нужно добвить перед функцией экстакции компоненты даты `.dt`. При этом стоит все же брать не индекс дня недели, а наименование, так будет понятнее: `df['first_order_dt'].dt.day_name()`.
#
#
# * Долю вернувшихся, опять же, удобнее считать через группировку и расчет среднего по `is_two`.
#
#
# * Поскольку анализ у нас направлен именно на возвращаемость клиентов, на графике было бы логичнее отобразить возвращаемость, а не распределение пользователей по сегментам.
#
#
# * На графиках для каждого сегмента лучше отобразить только одну из долей. Поскольку у нас каждый сегмент подразедяляется только на две подгруппы, они являются дополняющими друг для друга, если мы отображаем обе, график уже становится сложнее, но дополнительной информативности это не дает.
#
#
# * В выводах было бы неплохо также предположить, почему в топ и антитоп выбиваются определенные дни недели? Какие суждения относительно этого можно выстроить?
#
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; border-radius: 10px;  padding: 15px">
# <h3> Комментарий студента <a class="tocSkip"></h3>
#
# Спасибо за примеры с упрощением кода, постарался исправить.
# </div>

# %% [markdown]
# ---
#
# **Задача 4.3.2.** Изучите, как средний интервал между заказами влияет на удержание клиентов.
#
# - Рассчитайте среднее время между заказами для двух групп пользователей:
#     - совершившие 2–4 заказа;
#     - совершившие 5 и более заказов.
# - Исследуйте, как средний интервал между заказами влияет на вероятность повторного заказа, и сделайте выводы.
#
# ---

# %% [markdown]
# Рассчитаем среднее время между заказами для пользователей совершивших 2–4 заказа.

# %%
grouped_by_is_two = users_df[(users_df['is_two']) & (users_df['is_five'] != True)]['avg_days_since_prev'];

# %%
print(f'Среднее время между заказами для пользователей совершивших от 2 до 4 заказов. {round(grouped_by_is_two.mean(), 2)}')
# Out:
# Среднее время между заказами для пользователей совершивших от 2 до 4 заказов. 21.229999542236328

# %%
plt.figure(figsize=(10, 5))
grouped_by_is_two.plot(
    kind="hist",
    alpha=0.75,
    bins=37,
    edgecolor="black"
)
plt.title('Распределение пользователей совершивших 2–4 заказа по среднему количеству дней между заказами')
plt.xlabel('Количеству дней')
plt.ylabel('Количество пользователей')
plt.grid()
plt.show()

# %% [markdown]
# Рассчитаем среднее время между заказами для пользователей совершивших 5 и более заказов.

# %%
grouped_by_is_five = users_df[users_df['is_five']]['avg_days_since_prev'];

# %%
print(f'Среднее время между заказами для пользователей совершивших 5 более заказов. {round(grouped_by_is_five.mean(), 2)}')
# Out:
# Среднее время между заказами для пользователей совершивших 5 более заказов. 9.899999618530273

# %%
plt.figure(figsize=(10, 5))
grouped_by_is_five.plot(
    kind="hist",
    alpha=0.75,
    bins=37,
    edgecolor="black"
)
plt.title('Распределение пользователей совершивших 5 и более заказов по среднему количеству дней между заказами')
plt.xlabel('Количеству дней')
plt.ylabel('Количество пользователей')
plt.grid()
plt.show()

# %% [markdown]
# Можно сделать вывод, что чем меньше средний интервал тем больше вероятность потворного заказа. Всплески близкие к нулю возможно объясняются тем что это заказы пользователей которые сделали всего один заказ и с небольшой разницей по времени докупили билеты на это же мероприятие.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ возвращаемости по количеству дней между заказами <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> По расчетам все верно!
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * Важно иметь в виду, что среднее значение довольно сильно зависит от характера распределения, если есть какие-то сильные выбросы, они могут утянуть среднее значение вверх, хотя основаня масса значений будет гораздо ниже. Поэтому здесь важно было бы построить в том числе гистограммы, чтобы видеть всю картину в данных.
#
#
# * В выводах, опять же, было бы неплохо предположить, почему получается именно такой результат.
#
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; border-radius: 10px;  padding: 15px">
# <h3> Комментарий студента <a class="tocSkip"></h3>
#
# Добавил графики и обновил вывод.
# </div>

# %% [markdown]
# ---
#
# ### Корреляционный анализ количества покупок и признаков пользователя
#
# Изучите, какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок. Для этого используйте универсальный коэффициент корреляции `phi_k`, который позволяет анализировать как числовые, так и категориальные признаки.
#
# ---
#
# **Задача 4.4.1:** Проведите корреляционный анализ:
# - Рассчитайте коэффициент корреляции `phi_k` между признаками профиля пользователя и числом заказов (`total_orders`). При необходимости используйте параметр `interval_cols` для определения интервальных данных.
# - Проанализируйте полученные результаты. Если полученные значения будут близки к нулю, проверьте разброс данных в `total_orders`. Такое возможно, когда в данных преобладает одно значение: в таком случае корреляционный анализ может показать отсутствие связей. Чтобы этого избежать, выделите сегменты пользователей по полю `total_orders`, а затем повторите корреляционный анализ. Выделите такие сегменты:
#     - 1 заказ;
#     - от 2 до 4 заказов;
#     - от 5 и выше.
# - Визуализируйте результат корреляции с помощью тепловой карты.
# - Ответьте на вопрос: какие признаки наиболее связаны с количеством заказов?
#
# ---

# %% [markdown]
# Рассчитаем коэффициент корреляции между признаками профиля пользователя и числом заказов (`total_orders`).

# %%
corr_columns = [
    'first_order_device',
    'first_order_region',
    'first_order_service',
    'first_order_event',
    'avg_revenue_rub',
    'avg_tickets_count',
    'avg_days_since_prev',
    'avg_tickets_count_segment',
    'first_order_weekday',
    'total_orders'
]

# Вычисляем корреляционную матрицу с использованием phi_k
correlation_matrix = users_df[corr_columns].phik_matrix(interval_cols=['avg_revenue_rub', 'avg_tickets_count', 'avg_days_since_prev', 'total_orders'])

# Выводим результат
print('Корреляционная матрица с коэффициентом phi_k для переменной total_orders')
correlation_matrix.loc[correlation_matrix.index != 'total_orders'][['total_orders']].sort_values(by='total_orders', ascending=False)
# Out:
# Корреляционная матрица с коэффициентом phi_k для переменной total_orders
#                            total_orders
# avg_days_since_prev            0.295687
# avg_tickets_count              0.230637
# avg_revenue_rub                0.226949
# avg_tickets_count_segment      0.206668
# first_order_region             0.124257
# first_order_weekday            0.053700
# first_order_service            0.029803
# first_order_event              0.028181
# first_order_device             0.018514

# %% [markdown]
# Наибольшая корреляция числа заказов наблюдается со средним количеством дней между заказами (0.30), средним количеством билдетов в заказе (0.23), средней выручкой (0.23) и средним количесмтвом билетов заказе (0.21). Для остальных признаков коэффициент корреляции снижается с 0.12 до 0. В целом корреляция слабая.

# %% [markdown]
# Визуализируем результат корреляции.

# %%
plt.figure(figsize=(2, 6))
data_heatmap = correlation_matrix.loc[correlation_matrix.index != 'total_orders'][['total_orders']].sort_values(by='total_orders', ascending=False)
sns.heatmap(data_heatmap,
            annot=True,
            fmt='.2f',
            cmap='coolwarm',
            linewidths=0.5,
            cbar=False
           )
plt.title('Тепловая карта коэффициента phi_k \n для данных total_orders')
plt.xlabel('Количество заказов')
plt.show()

# %% [markdown]
# Повторим корреляционный анализ для сегментов где пользователи имеют от 2 до 4 и от 5 и выше заказов.

# %%
correlation_matrix = users_df[(users_df['is_two']) & (users_df['is_five'] == False)][corr_columns].phik_matrix(interval_cols=['avg_revenue_rub', 'avg_tickets_count', 'avg_days_since_prev', 'total_orders'])
print('Корреляционная матрица с коэффициентом phi_k для переменной total_orders у пользователей сделавших от 2 до 4 заказов')
correlation_matrix.loc[correlation_matrix.index != 'total_orders'][['total_orders']].sort_values(by='total_orders', ascending=False)
# Out:
# Корреляционная матрица с коэффициентом phi_k для переменной total_orders у пользователей сделавших от 2 до 4 заказов
#                            total_orders
# avg_days_since_prev            0.381103
# avg_tickets_count              0.367882
# avg_revenue_rub                0.108813
# avg_tickets_count_segment      0.074984
# first_order_service            0.058973
# first_order_device             0.006916
# first_order_region             0.000000
# first_order_event              0.000000
# first_order_weekday            0.000000

# %%
plt.figure(figsize=(2, 6))
data_heatmap = correlation_matrix.loc[correlation_matrix.index != 'total_orders'][['total_orders']].sort_values(by='total_orders', ascending=False)
sns.heatmap(data_heatmap,
            annot=True,
            fmt='.2f',
            cmap='coolwarm',
            linewidths=0.5,
            cbar=False
           )
plt.title('Тепловая карта коэффициента phi_k \n для данных total_orders у пользователей сделавших от 2 до 4 заказов')
plt.xlabel('Количество заказов')
plt.show()

# %% [markdown]
# Для пользователей сделавших от 2 до 4 заказов наблюдается умеренная корреляция количества заказов со средним количеством дней между заказами (0.38) и средним количеством билетов в заказе (0.37). Для остальных признаков коэффициент корреляции снижается с 0.11 до 0.

# %%
correlation_matrix = users_df[users_df['is_five']][corr_columns].phik_matrix(interval_cols=['avg_revenue_rub', 'avg_tickets_count', 'avg_days_since_prev', 'total_orders'])
print('Корреляционная матрица с коэффициентом phi_k для переменной total_orders у пользователей сделавших 5 и более заказов')
correlation_matrix.loc[correlation_matrix.index != 'total_orders'][['total_orders']].sort_values(by='total_orders', ascending=False)
# Out:
# Корреляционная матрица с коэффициентом phi_k для переменной total_orders у пользователей сделавших 5 и более заказов
#                            total_orders
# avg_days_since_prev            0.689297
# avg_revenue_rub                0.244635
# avg_tickets_count_segment      0.196510
# first_order_region             0.178102
# avg_tickets_count              0.162516
# first_order_weekday            0.095230
# first_order_event              0.041534
# first_order_device             0.000000
# first_order_service            0.000000

# %%
plt.figure(figsize=(2, 6))
data_heatmap = correlation_matrix.loc[correlation_matrix.index != 'total_orders'][['total_orders']].sort_values(by='total_orders', ascending=False)
sns.heatmap(data_heatmap,
            annot=True,
            fmt='.2f',
            cmap='coolwarm',
            linewidths=0.5,
            cbar=False
           )
plt.title('Тепловая карта коэффициента phi_k \n для данных total_orders у пользователей сделавших 5 и более заказов')
plt.xlabel('Количество заказов')
plt.show()

# %% [markdown]
# Для пользователей сделавших от 5 и более заказов наблюдается сильная корреляция количества заказов со средним количеством дней между заказами (0.7). Для остальных признаков коэффициент корреляции снижается с 0.24 до 0.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Анализ корреляции <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> С этим заданием тоже справились! Здорово, что также проверяешь, насколько сильно меняются оценки, если смотреть отдельно по сегментам. В целом для этого эксперимента можно было бы дополнительно создать столбец с разделением на сегменты по количеству заказов, а затем посчитать корреляцию показателей с этим сегментированным признаком.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b>
#
# * При расчете phi-корреляции стоит явным образом задавать параметр `interval_cols` и указывать в нем количественные признаки с большим разнообразием значений, чтобы алгоритм не пытался распознать их самостоятельно, и не относил в этот перечень все, что задано числами.
#
#
# * В выводах было бы неплохо сделать более явный акцент на том, что поведение клиентов во времени и количество билетов важнее для объяснения повторных покупок, чем их демография или первый выбор сервиса, что в целом логично (не так важно, на что пошел пользователь в первый раз, сколько общий его характер посещения досуговых мероприятий) и как раз согласуется с нашими результатами на предыдущих шагах.
#
# </div>

# %% [markdown]
# ### Промежуточные выводы
#
# Анализ взаимосвязи данных показал, что:
#
# - Наибольший процент пользователей, сделавших более одного заказа в зависимости от типа первого мероприятия это выставки (64%), театр (64%) и концерт (62%). Чаще всего возвращаются пользователи делавшие первый заказ с компьютера (64%). Доля вернувшихся пользователей делавших первый заказ с мобильных устройств (61%). Чаще всего такие пользователи делают заказ с мобильного устройства (80%). Больше всего вернувшихся пользователей делавшие первый заказ в Шанырском регионе (70%), Светополянском округе (66%) и Широковской области (65%).  Чаще всего возвращаются пользователи делавшие первый заказ с помощью следующих сервисов: край билетов (65%), дом культуры (65%), билеты в руки (63%), весь в билетах (63%) и прачечная (63%).
# - Пользователи которые совершили первый заказ на спортивные мероприятия совершают заказы чаще, чем пользователи, оформившие свой первый заказ на концерты. Среднее время между заказами у пользователей которые совершили первый заказ на спортивные мероприятия - 9 дней, у пользователей которые совершили первый заказ на концерты - 17 дней.
# - В регионах, где больше всего пользователей посещают мероприятия, доля повторных заказов не выше, чем в менее активных регионах. Доля повторных заказов больше всего в Шанырском регионе (70%), где доля пользователей примерно 2% от общего количества.
# - Пользователи сделавшие 2-4 заказа в среднем тратят на билет до 300 рублей, а пользователи сделавшие от 5 и более заказов -  500 рублей.
# - Чаще всего пользователи делающие повторные заказы покупают от 2 до 3 билетов.
# - Больше всего первый заказ пользователи делали в субботу, меньше всего в воскресенье. Доля пользователей совершивших повторые заказы в целом не меняется в зависимости от для неделеи первого заказа и равна ~ 61%. Можно сделать вывод что день недели первого заказа не влияет на возврат клиента.
# - Среднее время между заказами для пользователей совершивших 2–4 заказа - 21 день, среднее время между заказами для пользователей совершивших 5 и более заказов - 10 дней.
# - Для пользователей сделавших от 2 до 4 заказов наблюдается умеренная корреляция количества заказов со средним количеством дней между заказами (0.38) и средним количеством билетов в заказе (0.37). Для пользователей сделавших от 5 и более заказов наблюдается сильная корреляция количества заказов со средним количеством дней между заказами (0.7).

# %% [markdown]
# ## Общий вывод и рекомендации
#
# В конце проекта напишите общий вывод и рекомендации: расскажите заказчику, на что нужно обратить внимание. В выводах кратко укажите:
#
# - **Информацию о данных**, с которыми вы работали, и то, как они были подготовлены: например, расскажите о фильтрации данных, переводе тенге в рубли, фильтрации выбросов.
# - **Основные результаты анализа.** Например, укажите:
#     - Сколько пользователей в выборке? Как распределены пользователи по числу заказов? Какие ещё статистические показатели вы подсчитали важным во время изучения данных?
#     - Какие признаки первого заказа связаны с возвратом пользователей?
#     - Как связаны средняя выручка и количество билетов в заказе с вероятностью повторных покупок?
#     - Какие временные характеристики влияют на удержание (день недели, интервалы между покупками)?
#     - Какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок согласно результатам корреляционного анализа?
# - Дополните выводы информацией, которая покажется вам важной и интересной. Следите за общим объёмом выводов — они должны быть компактными и ёмкими.
#
# В конце предложите заказчику рекомендации о том, как именно действовать в его ситуации. Например, укажите, на какие сегменты пользователей стоит обратить внимание в первую очередь, а какие нуждаются в дополнительных маркетинговых усилиях.

# %% [markdown]
# В ходе исследования проанализировали данные 290611 заказов Яндекс Афишы за 2024 год. Данные включали персональную информацию клиентов и особенности заказов. Акцент исследования был на том, чтобы найти взаимосвязи между повторными покупками клиентов и другими факторами. Среди них: особенности первого заказа, общее количество заказов, средняя выручка, среднее количество билетов в заказе, среднее количество дней между заказами.
#
# ### Информация о данных
#
# В результате предобработки данных были выполнены следующие действия:
# - Добавилен новый столбец `revenue_rub` с выручкой в рублях;
# - Оптимизирована разрядность в столбцах `order_id`, `tickets_count`, `days_since_prev` и `event_id`;
# - Нормализованы данные в категориальных столбцах `service_name`, `region_name` и `city_name`;
# - Отфильтрованы значения по 99 перцентилю столбца `revenue_rub`. Объем отфильтрованных данных 1%.
#
# ### Основные результаты анализа
#
# Был создан датафрейм с данными пользователей. Общее количество пользователей в итоговой выборке - **21477**. Доля пользователей, совершивших 2 и более заказов **61%**, доля пользователей, совершивших 5 и более заказов **28%**. Средняя выручка с одного заказа **551.12**.
#
# Среди признаков связанных с возвратом пользователей можно отметить тип мероприятия (выставки - **64%**, театр - **64%** и концерт - **62%**), тип устройства (компьютер - **64%**, мобильные устройства - **60%**), регион (Шанырский регион -  **70%**, Светополянский округ - **66%** и Широковская область - **65%**), сервис (край билетов - **65%**, дом культуры - **65%**, билеты в руки - **63%**, весь в билетах - **63%** и прачечная - **63%**).
#
# Пользователи сделавшие 2-4 заказа в среднем тратят на билет до **300** рублей, а пользователи сделавшие от 5 и более заказов - **500** рублей. Чаще всего пользователи берут **2** или **3** билета, доля таких пользователей - **73%**.
#
# День недели не имеет сильного влияния на повторные заказы, но стоит отметить что в субботу в целом делают больше заказов чем в остальные дни. У пользователей совершающих больше заказов меньше средний интервал между покупками.
#
# Согласно результатам корреляционного анализа с числом покупок может связано количество дней между заказами и количество билетов в заказе.
#
# ### Рекомендации
#
# В качестве рекомендаций стоит обратить внимание на удержание клиентов делающих заказы в котором 1 билет или более 3 билетов. Им можно предложить более выгодные условия или дополнительные бонусы. Также рекомендуется обратить внимание на менее популярные категории мероприятий, возможно нужна какая-то дополнителдьная реклама для таких мероприятий. Возможно следует дать дополнительные скидки клиентам делающим заказы с небольшим промежутком между заказами.

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Итоговые выводы <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-success">
# <b>Отлично ✅:</b> С задачей справились! Все ключевые моменты отражены, что позволяет быстро ознакомиться с процессом работы и результатом, не вдаваясь в технический детали. Здорово, что завершаешь проект рекомендациями, основанные на выявленных закономерностях. Предложенные рекомендации логично следуют из анализа и могут быть непосредственно реализованы в маркетинговых стратегиях подогревания и удержания.
#
# </div>

# %% [markdown]
# ## Финализация проекта и публикация в Git
#
# Когда вы закончите анализировать данные, оформите проект, а затем опубликуйте его.
#
# Выполните следующие действия:
#
# 1. Создайте файл `.gitignore`. Добавьте в него все временные и чувствительные файлы, которые не должны попасть в репозиторий.
# 2. Сформируйте файл `requirements.txt`. Зафиксируйте все библиотеки, которые вы использовали в проекте.
# 3. Вынести все чувствительные данные (параметры подключения к базе) в `.env`файл.
# 4. Проверьте, что проект запускается и воспроизводим.
# 5. Загрузите проект в публичный репозиторий — например, на GitHub. Убедитесь, что все нужные файлы находятся в репозитории, исключая те, что в `.gitignore`. Ссылка на репозиторий понадобится для отправки проекта на проверку. Вставьте её в шаблон проекта в тетрадке Jupyter Notebook перед отправкой проекта на ревью.

# %% [markdown]
# **Вставьте ссылку на проект в этой ячейке тетрадки перед отправкой проекта на ревью.**

# %% [markdown]
# https://github.com/alexilin83/ds_project

# %% [markdown]
# <div style="border:solid #D3D3D3 2px;  border-radius: 10px; padding: 15px">
# <h3> Комментарий ревьюера <a class="tocSkip"></h3>
# <h4> Публикация в Git <a class="tocSkip"></h4>
#
# <div style="border-radius: 10px" class="alert alert-block alert-danger">
# <b>Нужно доработать ❌:</b>
#
# * По ссылке нет самого проекта (jupyter-ноутбука), только репозиторий для него.
#
#
# * Не забудь, что выкладывать проект нужно с засекреченным подключением к БД.
#
# </div>
# <div style="border-radius: 10px" class="alert alert-warning">
# <b>Рекомендации💡:</b> Можно заполнить readme полезной информацией о проекте, зафиксировать цели, указать ключевые моменты и полученные выводы.
#
# </div>

# %% [markdown]
# <div style="border:solid blue 2px; border-radius: 10px;  padding: 15px">
# <h3> Комментарий студента <a class="tocSkip"></h3>
#
# Обновил репозиторий.
# </div>

# %% [markdown]
# <div style="border:solid Green 2px; border-radius: 10px;  padding: 40px">
# <h3>Общий вывод по проекту <a class="tocSkip"></h3>
#
# Алексей, спасибо за твой проект! У тебя хорошая работа! В тебе виден будущий профессионал своего дела :) Однако есть еще моменты, которые требуют твоего внимания. Кратко пройдусь по впечатлениям.
#
# **Полнота:** все требуемые задачи были выполнены!
#
# **Корректность:**
#
# * <span style="color:Red;">Необходимо засекретить подключение к БД, чтобы не скомпромитировать явки и пароли. Не забываем загрузить файл в Git.</span>
# * <span style="color:Red;">Необходимо расширить предобработку данных. Проверка на некорректные значения - важный этап предобработки по умолчанию.</span>
# * <span style="color:Red;">Необходимо скорректировать расчет возвращаемости по сегментам. Сейчас вместо этого посчитано распределение по сегментам среди вернувшихся.</span>
#
# **Аналитическая проницательность:** ты верно подмечаешь все ключевые нюансы данных, даешь дельные рекомендации! Местами можно чуть углубить суждения, фиксировать не только то, что наблюдаем, но и предполагать, почему получилось именно так.
#
# **Эффективность кода:** по этому критерию в целом тоже все супер! В некоторых местах можно использовать чуть более удобные и компактные методы, зациклить повторяющиеся действия.
#
# **Оформление:** им тоже важно не пренебрегать! Оформление тесно связано с удобством восприятия предоставляемой информации и созданием впечатления о работе. Твоя работа в целом довольно аккуратная - выделены разделы, грамотно оформлены графики, в выводах расставлены акценты через форматирование, код сопровождается краткими комментариями, но еще есть некоторый потенциал для улучшений (см. по ходу работы).
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉
#
# <img src="https://99px.ru/sstorage/86/2015/12/image_86271215043043632690.gif" />

# %% [markdown]
# Спасибо тебе за фидбэк. Постараюсь все учесть в будущем. Для меня вот причинно-следственные связи вызывают затруднения. Сложновато бывает понять, что нужно удалять из выборки а что нет. Как логически дойти до то что какие данные будут мешать анализу а какие нет.
